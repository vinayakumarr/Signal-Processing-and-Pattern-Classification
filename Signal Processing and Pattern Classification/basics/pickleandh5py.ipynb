# %%
import pickle

# %%
Courses = { "McA": "MCA", "mtech": "mCa" }

# %%
pickle.dump( Courses, open( "data/save.p", "wb" ) )

# %%
import pickle
Courses = pickle.load( open( "data/save.p", "rb" ) )
print(Courses)
# Out:
# {'mtech': 'mCa', 'McA': 'MCA'}

# %%
#In Python 2, you can speed up your pickle access with cPickle
import cPickle as pickle

# %%
import numpy as np
import h5py
a = np.random.random(size=(100,20))
h5f = h5py.File('data/places.h5', 'w')
h5f.create_dataset('Coimatore', data=a)
h5f.close()

# %%
hf = h5py.File('data/places.h5', 'r')

# %%
hf.keys()
# Out:
# [u'Coimatore']

# %%
n1 = hf.get('Coimatore')

# %%
print(a)
# Out:
# [[ 0.33412934  0.0354671   0.03424124 ...,  0.82633875  0.48229887
#    0.98241557]
#  [ 0.11882759  0.01912331  0.86190162 ...,  0.46347191  0.08417392
#    0.74313231]
#  [ 0.61045655  0.66399382  0.36930377 ...,  0.81665796  0.27434181
#    0.78094389]
#  ...,
#  [ 0.04744102  0.92129318  0.53562008 ...,  0.21281105  0.47548767
#    0.94044184]
#  [ 0.49178111  0.9164625   0.8547971  ...,  0.09878714  0.94332963
#    0.46193126]
#  [ 0.36357596  0.43156031  0.05778233 ...,  0.55206482  0.52448766
#    0.50722936]]

# %%
# List all groups
print("Keys: %s" % hf.keys())
a_group_key = list(hf.keys())[0]

# Get the data
data = list(hf[a_group_key])
# Out:
# Keys: [u'Coimatore']

# %%
print(a_group_key)
# Out:
# Coimatore

# %%
print(data)
# Out:
# [array([ 0.33412934,  0.0354671 ,  0.03424124,  0.89937763,  0.09572119,
#         0.82996797,  0.07969331,  0.92355212,  0.44463925,  0.400989  ,
#         0.06538742,  0.29574138,  0.29177662,  0.75951842,  0.84803715,
#         0.63214215,  0.91844603,  0.82633875,  0.48229887,  0.98241557]), array([ 0.11882759,  0.01912331,  0.86190162,  0.20284504,  0.4912432 ,
#         0.32814231,  0.88265262,  0.43564324,  0.01234813,  0.04796363,
#         0.57409627,  0.90118027,  0.71926124,  0.43430019,  0.25483602,
#         0.17677151,  0.04328219,  0.46347191,  0.08417392,  0.74313231]), array([ 0.61045655,  0.66399382,  0.36930377,  0.33835312,  0.18730692,
#         0.44042376,  0.87502288,  0.53053159,  0.1430692 ,  0.41255183,
#         0.09101736,  0.58020815,  0.902813  ,  0.09091128,  0.53084077,
#         0.73222609,  0.30134066,  0.81665796,  0.27434181,  0.78094389]), array([ 0.50487673,  0.23710423,  0.80385224,  0.51063001,  0.86233119,
# ...
